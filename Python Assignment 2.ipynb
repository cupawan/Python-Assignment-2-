# %% [markdown]
# # Python Assignment 2

# %% [raw]
# 1.Create the below pattern using nested for loop in Python.
#
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
def pyramid(rows):
    for i in range(rows):
        print("* "*(i+1) + " "*(rows-i))
    for j in range(1,rows):
        print("* "*(rows-j) +  " "*(j))

# %%
pyramid(5)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [raw]
# 2. Write a Python program to reverse a word after accepting the input from the user.
# Sample Output:
# Input word: ineuron
# Output: norueni

# %%
user = input("Enter a word: ")
reverse_word = user[len(user)::-1]
print(reverse_word)
# Out:
# Enter a word: ineuron
# norueni
